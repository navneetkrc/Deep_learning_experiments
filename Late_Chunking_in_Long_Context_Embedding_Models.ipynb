# %% [markdown]
# # [Late Chunking](https://jina.ai/news/late-chunking-in-long-context-embedding-models)
#
# This notebooks explains how the "Late Chunking" can be implemented. First you need to install the requirements:

# %%
# !pip install transformers==4.43.4

# %% [markdown]
# Then we load a model which we want to use for the embedding. We choose `jinaai/jina-embeddings-v2-base-en` but any other model which supports mean pooling is possible. However, models with a large maximum context-length are preferred.

# %%
from transformers import AutoModel
from transformers import AutoTokenizer

# load model and tokenizer
tokenizer = AutoTokenizer.from_pretrained('jinaai/jina-embeddings-v2-base-en', trust_remote_code=True)
model = AutoModel.from_pretrained('jinaai/jina-embeddings-v2-base-en', trust_remote_code=True)

# %% [markdown]
# Now we define the text which we want to encode and split it into chunks. The `chunk_by_sentences` function also returns the span annotations.
# Those specify the number of tokens per chunk which is needed for the chunked pooling.

# %%
def chunk_by_sentences(input_text: str, tokenizer: callable):
    """
    Split the input text into sentences using the tokenizer
    :param input_text: The text snippet to split into sentences
    :param tokenizer: The tokenizer to use
    :return: A tuple containing the list of text chunks and their corresponding token spans
    """
    inputs = tokenizer(input_text, return_tensors='pt', return_offsets_mapping=True)
    punctuation_mark_id = tokenizer.convert_tokens_to_ids('.')
    sep_id = tokenizer.convert_tokens_to_ids('[SEP]')
    token_offsets = inputs['offset_mapping'][0]
    token_ids = inputs['input_ids'][0]
    chunk_positions = [
        (i, int(start + 1))
        for i, (token_id, (start, end)) in enumerate(zip(token_ids, token_offsets))
        if token_id == punctuation_mark_id
        and (
            token_offsets[i + 1][0] - token_offsets[i][1] > 0
            or token_ids[i + 1] == sep_id
        )
    ]
    chunks = [
        input_text[x[1] : y[1]]
        for x, y in zip([(1, 0)] + chunk_positions[:-1], chunk_positions)
    ]
    span_annotations = [
        (x[0], y[0]) for (x, y) in zip([(1, 0)] + chunk_positions[:-1], chunk_positions)
    ]
    return chunks, span_annotations

# %% [markdown]
# In production, you should use more advanced and robust segmentation method such as Jina AI Tokenizer API https://jina.ai/tokenizer#apiform.

# %%
import requests

def chunk_by_tokenizer_api(input_text: str, tokenizer: callable):
    # Define the API endpoint and payload
    url = 'https://tokenize.jina.ai/'
    payload = {
        "content": input_text,
        "return_chunks": "true",
        "max_chunk_length": "1000"
    }

    # Make the API request
    response = requests.post(url, json=payload)
    response_data = response.json()

    # Extract chunks and positions from the response
    chunks = response_data.get("chunks", [])
    chunk_positions = response_data.get("chunk_positions", [])

    # Adjust chunk positions to match the input format
    span_annotations = [(start, end) for start, end in chunk_positions]

    return chunks, span_annotations

# %% [markdown]
# Now let's try to segement a toy example.

# %%
input_text = """
## Samsung Galaxy S25 Support Documentation: Common Issues and Solutions

The Samsung Galaxy S25 series, including the S25, S25+, and S25 Ultra, is a flagship lineup packed with advanced features. However, like any new smartphone release, users have reported various issues. This support document outlines common problems, troubleshooting steps, and solutions to ensure optimal performance.

---

### **Common Issues with the Galaxy S25 Series**

#### **1. Display Issues**
- **Problems:** Users have reported scrolling lag, screen flickering, and dim brightness.
- **Causes:** These issues are often software-related or linked to display settings.
- **Solutions:**
  - Disable Always-On Display (AOD) by entering Safe Mode and uninstalling the AOD app[5][8].
  - Adjust screen brightness in *Settings > Display > Screen mode* and use the Vividness slider for preferred color tuning[8].
  - Increase touch sensitivity via *Settings > Display* if taps are missed or scrolling feels unresponsive[8].

#### **2. Overheating**
- **Problems:** Some Galaxy S25 devices experience overheating during intensive use.
- **Causes:** Likely related to the Snapdragon 8 Elite chipset or high-performance settings.
- **Solutions:**
  - Avoid using the device in direct sunlight or while charging.
  - Enable power-saving mode in *Settings > Battery* to reduce strain on the processor[3][9].
  - Check for software updates that may address chipset optimization[9].

#### **3. Camera Problems**
- **Problems:** Issues include streaks in photos taken under strong light conditions and inconsistent autofocus.
- **Causes:** Software bugs or hardware calibration errors.
- **Solutions:**
  - Update camera software via *Settings > Software Update*[3][9].
  - Clear cache for the camera app in *Settings > Apps > Camera > Storage > Clear Cache*[4].
  - If problems persist, visit a Samsung service center for hardware inspection[9].

#### **4. Battery Drain**
- **Problems:** Faster-than-expected battery depletion even under moderate usage.
- **Causes:** High refresh rates, background apps, or Always-On Display.
- **Solutions:**
  - Check battery usage in *Settings > Battery and Device Care* and restrict power-hungry apps[9].
  - Reduce refresh rate to Adaptive or Standard mode via *Settings > Display*[9].
  - Disable features like Always-On Display and Location Services when not needed[9].

#### **5. App Notification Delays**
- **Problems:** Notifications from apps like WhatsApp and Facebook are delayed.
- **Causes:** Battery optimization settings or app-specific bugs.
- **Solutions:**
  - Disable battery optimization for affected apps in *Settings > Battery > Background Usage Limits*[5].
  - Ensure Do Not Disturb mode is turned off[9].
  - Update apps to their latest versions via Google Play Store[3].

#### **6. Android Auto Connectivity Issues**
- **Problems:** Some users report that Android Auto fails to recognize the device.
- **Causes:** Compatibility issues with car head units or software bugs.
- **Solutions:**
  - Try a different USB cable or port.
  - Clear cache for Android Auto via *Settings > Apps > Android Auto > Storage > Clear Cache*[4].
  - Wait for updates from Google to address compatibility issues[3].

---

### **Troubleshooting Steps**

#### **Soft Reset (Force Restart)**
If your device becomes unresponsive:
1. Press and hold the Volume Down key + Side key simultaneously for at least 7 seconds until the phone restarts[4].

#### **Clear App Cache**
To resolve app-related issues:
1. Navigate to *Settings > Battery and Device Care*.
2. Tap "Optimize Now" to clear cache data[4].

#### **Factory Reset**
To resolve persistent problems:
1. Go to *Settings > General Management > Reset > Factory Data Reset*.
2. Confirm reset after backing up important data, as this erases all personal information[5][6].

#### **Safe Mode Troubleshooting**
For issues caused by third-party apps:
1. Restart into Safe Mode by holding Volume Down + Side key until the Samsung logo appears.
2. Uninstall problematic apps via *Settings > Apps*[4][5].

---

### **Hardware-Specific Features**

#### Galaxy S25 Ultra
The Ultra model includes unique features such as:
- S Pen functionality for advanced productivity tasks[2].
- Enhanced camera capabilities like macro photography and 8K video recording[7].

#### Wireless Charging
All models support wireless charging but may require removing accessories or cases for stable charging performance[2].

---

### **Service Center Support**
If troubleshooting fails:
1. Visit a Samsung service center for hardware repairs or replacements.
2. Check service center wait times online to minimize delays[4].

---

### Conclusion
The Samsung Galaxy S25 series offers cutting-edge technology but may encounter occasional issues typical of new devices. By following these troubleshooting steps and solutions, users can resolve most problems efficiently while maximizing their smartphone experience. For unresolved issues, professional assistance is available through Samsung service centers.



"""


# determine chunks
chunks, span_annotations = chunk_by_sentences(input_text, tokenizer)
print('Chunks:\n- "' + '"\n- "'.join(chunks) + '"')
# Out:
# Chunks:
# - "
# ## Samsung Galaxy S25 Support Documentation: Common Issues and Solutions
#
# The Samsung Galaxy S25 series, including the S25, S25+, and S25 Ultra, is a flagship lineup packed with advanced features."
# - " However, like any new smartphone release, users have reported various issues."
# - " This support document outlines common problems, troubleshooting steps, and solutions to ensure optimal performance."
# - "
#
# ---
#
# ### **Common Issues with the Galaxy S25 Series**
#
# #### **1."
# - " Display Issues**
# - **Problems:** Users have reported scrolling lag, screen flickering, and dim brightness."
# - "
# - **Causes:** These issues are often software-related or linked to display settings."
# - "
# - **Solutions:**
#   - Disable Always-On Display (AOD) by entering Safe Mode and uninstalling the AOD app[5][8]."
# - "
#   - Adjust screen brightness in *Settings > Display > Screen mode* and use the Vividness slider for preferred color tuning[8]."
# - "
#   - Increase touch sensitivity via *Settings > Display* if taps are missed or scrolling feels unresponsive[8]."
# - "
#
# #### **2."
# - " Overheating**
# - **Problems:** Some Galaxy S25 devices experience overheating during intensive use."
# - "
# - **Causes:** Likely related to the Snapdragon 8 Elite chipset or high-performance settings."
# - "
# - **Solutions:**
#   - Avoid using the device in direct sunlight or while charging."
# - "
#   - Enable power-saving mode in *Settings > Battery* to reduce strain on the processor[3][9]."
# - "
#   - Check for software updates that may address chipset optimization[9]."
# - "
#
# #### **3."
# - " Camera Problems**
# - **Problems:** Issues include streaks in photos taken under strong light conditions and inconsistent autofocus."
# - "
# - **Causes:** Software bugs or hardware calibration errors."
# - "
# - **Solutions:**
#   - Update camera software via *Settings > Software Update*[3][9]."
# - "
#   - Clear cache for the camera app in *Settings > Apps > Camera > Storage > Clear Cache*[4]."
# - "
#   - If problems persist, visit a Samsung service center for hardware inspection[9]."
# - "
#
# #### **4."
# - " Battery Drain**
# - **Problems:** Faster-than-expected battery depletion even under moderate usage."
# - "
# - **Causes:** High refresh rates, background apps, or Always-On Display."
# - "
# - **Solutions:**
#   - Check battery usage in *Settings > Battery and Device Care* and restrict power-hungry apps[9]."
# - "
#   - Reduce refresh rate to Adaptive or Standard mode via *Settings > Display*[9]."
# - "
#   - Disable features like Always-On Display and Location Services when not needed[9]."
# - "
#
# #### **5."
# - " App Notification Delays**
# - **Problems:** Notifications from apps like WhatsApp and Facebook are delayed."
# - "
# - **Causes:** Battery optimization settings or app-specific bugs."
# - "
# - **Solutions:**
#   - Disable battery optimization for affected apps in *Settings > Battery > Background Usage Limits*[5]."
# - "
#   - Ensure Do Not Disturb mode is turned off[9]."
# - "
#   - Update apps to their latest versions via Google Play Store[3]."
# - "
#
# #### **6."
# - " Android Auto Connectivity Issues**
# - **Problems:** Some users report that Android Auto fails to recognize the device."
# - "
# - **Causes:** Compatibility issues with car head units or software bugs."
# - "
# - **Solutions:**
#   - Try a different USB cable or port."
# - "
#   - Clear cache for Android Auto via *Settings > Apps > Android Auto > Storage > Clear Cache*[4]."
# - "
#   - Wait for updates from Google to address compatibility issues[3]."
# - "
#
# ---
#
# ### **Troubleshooting Steps**
#
# #### **Soft Reset (Force Restart)**
# If your device becomes unresponsive:
# 1."
# - " Press and hold the Volume Down key + Side key simultaneously for at least 7 seconds until the phone restarts[4]."
# - "
#
# #### **Clear App Cache**
# To resolve app-related issues:
# 1."
# - " Navigate to *Settings > Battery and Device Care*."
# - "
# 2."
# - " Tap "Optimize Now" to clear cache data[4]."
# - "
#
# #### **Factory Reset**
# To resolve persistent problems:
# 1."
# - " Go to *Settings > General Management > Reset > Factory Data Reset*."
# - "
# 2."
# - " Confirm reset after backing up important data, as this erases all personal information[5][6]."
# - "
#
# #### **Safe Mode Troubleshooting**
# For issues caused by third-party apps:
# 1."
# - " Restart into Safe Mode by holding Volume Down + Side key until the Samsung logo appears."
# - "
# 2."
# - " Uninstall problematic apps via *Settings > Apps*[4][5]."
# - "
#
# ---
#
# ### **Hardware-Specific Features**
#
# #### Galaxy S25 Ultra
# The Ultra model includes unique features such as:
# - S Pen functionality for advanced productivity tasks[2]."
# - "
# - Enhanced camera capabilities like macro photography and 8K video recording[7]."
# - "
#
# #### Wireless Charging
# All models support wireless charging but may require removing accessories or cases for stable charging performance[2]."
# - "
#
# ---
#
# ### **Service Center Support**
# If troubleshooting fails:
# 1."
# - " Visit a Samsung service center for hardware repairs or replacements."
# - "
# 2."
# - " Check service center wait times online to minimize delays[4]."
# - "
#
# ---
#
# ### Conclusion
# The Samsung Galaxy S25 series offers cutting-edge technology but may encounter occasional issues typical of new devices."
# - " By following these troubleshooting steps and solutions, users can resolve most problems efficiently while maximizing their smartphone experience."
# - " For unresolved issues, professional assistance is available through Samsung service centers."

# %% [markdown]
# Now we encode the chunks with the traditional and the context-sensitive late_chunking method:

# %%
def late_chunking(
    model_output: 'BatchEncoding', span_annotation: list, max_length=None
):
    token_embeddings = model_output[0]
    outputs = []
    for embeddings, annotations in zip(token_embeddings, span_annotation):
        if (
            max_length is not None
        ):  # remove annotations which go bejond the max-length of the model
            annotations = [
                (start, min(end, max_length - 1))
                for (start, end) in annotations
                if start < (max_length - 1)
            ]
        pooled_embeddings = [
            embeddings[start:end].sum(dim=0) / (end - start)
            for start, end in annotations
            if (end - start) >= 1
        ]
        pooled_embeddings = [
            embedding.detach().cpu().numpy() for embedding in pooled_embeddings
        ]
        outputs.append(pooled_embeddings)

    return outputs

# %%
# chunk before
embeddings_traditional_chunking = model.encode(chunks)

# chunk afterwards (context-sensitive chunked pooling)
inputs = tokenizer(input_text, return_tensors='pt')
model_output = model(**inputs)
embeddings = late_chunking(model_output, [span_annotations])[0]

# %% [markdown]
# Finally, we compare the similarity of the word "Berlin" with the chunks. The similarity should be higher for the context-sensitive chunked pooling method:

# %%
import numpy as np

cos_sim = lambda x, y: np.dot(x, y) / (np.linalg.norm(x) * np.linalg.norm(y))

s25_ultra_embedding = model.encode('Samsung Galaxy S25 Ultra')

for chunk, new_embedding, trad_embeddings in zip(chunks, embeddings, embeddings_traditional_chunking):
    print(f'similarity_new("Samsung Galaxy S25 Ultra", "{chunk}"):', cos_sim(s25_ultra_embedding, new_embedding))
    print(f'similarity_trad("Samsung Galaxy S25 Ultra", "{chunk}"):', cos_sim(s25_ultra_embedding, trad_embeddings))
# Out:
# similarity_new("Samsung Galaxy S25 Ultra", "
# ## Samsung Galaxy S25 Support Documentation: Common Issues and Solutions
#
# The Samsung Galaxy S25 series, including the S25, S25+, and S25 Ultra, is a flagship lineup packed with advanced features."): 0.8225856
# similarity_trad("Samsung Galaxy S25 Ultra", "
# ## Samsung Galaxy S25 Support Documentation: Common Issues and Solutions
#
# The Samsung Galaxy S25 series, including the S25, S25+, and S25 Ultra, is a flagship lineup packed with advanced features."): 0.8906413
# similarity_new("Samsung Galaxy S25 Ultra", " However, like any new smartphone release, users have reported various issues."): 0.8114611
# similarity_trad("Samsung Galaxy S25 Ultra", " However, like any new smartphone release, users have reported various issues."): 0.7030146
# similarity_new("Samsung Galaxy S25 Ultra", " This support document outlines common problems, troubleshooting steps, and solutions to ensure optimal performance."): 0.7745215
# similarity_trad("Samsung Galaxy S25 Ultra", " This support document outlines common problems, troubleshooting steps, and solutions to ensure optimal performance."): 0.6898514
# similarity_new("Samsung Galaxy S25 Ultra", "
#
# ---
#
# ### **Common Issues with the Galaxy S25 Series**
#
# #### **1."): 0.8323581
# similarity_trad("Samsung Galaxy S25 Ultra", "
#
# ---
#
# ### **Common Issues with the Galaxy S25 Series**
#
# #### **1."): 0.8233294
# similarity_new("Samsung Galaxy S25 Ultra", " Display Issues**
# - **Problems:** Users have reported scrolling lag, screen flickering, and dim brightness."): 0.7978771
# similarity_trad("Samsung Galaxy S25 Ultra", " Display Issues**
# - **Problems:** Users have reported scrolling lag, screen flickering, and dim brightness."): 0.7027988
# similarity_new("Samsung Galaxy S25 Ultra", "
# - **Causes:** These issues are often software-related or linked to display settings."): 0.8230563
# similarity_trad("Samsung Galaxy S25 Ultra", "
# - **Causes:** These issues are often software-related or linked to display settings."): 0.6326138
# similarity_new("Samsung Galaxy S25 Ultra", "
# - **Solutions:**
#   - Disable Always-On Display (AOD) by entering Safe Mode and uninstalling the AOD app[5][8]."): 0.8278724
# similarity_trad("Samsung Galaxy S25 Ultra", "
# - **Solutions:**
#   - Disable Always-On Display (AOD) by entering Safe Mode and uninstalling the AOD app[5][8]."): 0.69756806
# similarity_new("Samsung Galaxy S25 Ultra", "
#   - Adjust screen brightness in *Settings > Display > Screen mode* and use the Vividness slider for preferred color tuning[8]."): 0.8456359
# similarity_trad("Samsung Galaxy S25 Ultra", "
#   - Adjust screen brightness in *Settings > Display > Screen mode* and use the Vividness slider for preferred color tuning[8]."): 0.6951269
# similarity_new("Samsung Galaxy S25 Ultra", "
#   - Increase touch sensitivity via *Settings > Display* if taps are missed or scrolling feels unresponsive[8]."): 0.8405381
# similarity_trad("Samsung Galaxy S25 Ultra", "
#   - Increase touch sensitivity via *Settings > Display* if taps are missed or scrolling feels unresponsive[8]."): 0.68617576
# similarity_new("Samsung Galaxy S25 Ultra", "
#
# #### **2."): 0.8301299
# similarity_trad("Samsung Galaxy S25 Ultra", "
#
# #### **2."): 0.6934148
# similarity_new("Samsung Galaxy S25 Ultra", " Overheating**
# - **Problems:** Some Galaxy S25 devices experience overheating during intensive use."): 0.8170302
# similarity_trad("Samsung Galaxy S25 Ultra", " Overheating**
# - **Problems:** Some Galaxy S25 devices experience overheating during intensive use."): 0.7944771
# similarity_new("Samsung Galaxy S25 Ultra", "
# - **Causes:** Likely related to the Snapdragon 8 Elite chipset or high-performance settings."): 0.82600397
# similarity_trad("Samsung Galaxy S25 Ultra", "
# - **Causes:** Likely related to the Snapdragon 8 Elite chipset or high-performance settings."): 0.6656965
# similarity_new("Samsung Galaxy S25 Ultra", "
# - **Solutions:**
#   - Avoid using the device in direct sunlight or while charging."): 0.83527285
# similarity_trad("Samsung Galaxy S25 Ultra", "
# - **Solutions:**
#   - Avoid using the device in direct sunlight or while charging."): 0.6828663
# similarity_new("Samsung Galaxy S25 Ultra", "
#   - Enable power-saving mode in *Settings > Battery* to reduce strain on the processor[3][9]."): 0.83418345
# similarity_trad("Samsung Galaxy S25 Ultra", "
#   - Enable power-saving mode in *Settings > Battery* to reduce strain on the processor[3][9]."): 0.639427
# similarity_new("Samsung Galaxy S25 Ultra", "
#   - Check for software updates that may address chipset optimization[9]."): 0.8198631
# similarity_trad("Samsung Galaxy S25 Ultra", "
#   - Check for software updates that may address chipset optimization[9]."): 0.6435747
# similarity_new("Samsung Galaxy S25 Ultra", "
#
# #### **3."): 0.8269117
# similarity_trad("Samsung Galaxy S25 Ultra", "
#
# #### **3."): 0.6986505
# similarity_new("Samsung Galaxy S25 Ultra", " Camera Problems**
# - **Problems:** Issues include streaks in photos taken under strong light conditions and inconsistent autofocus."): 0.7913973
# similarity_trad("Samsung Galaxy S25 Ultra", " Camera Problems**
# - **Problems:** Issues include streaks in photos taken under strong light conditions and inconsistent autofocus."): 0.6931012
# similarity_new("Samsung Galaxy S25 Ultra", "
# - **Causes:** Software bugs or hardware calibration errors."): 0.7610494
# similarity_trad("Samsung Galaxy S25 Ultra", "
# - **Causes:** Software bugs or hardware calibration errors."): 0.6564991
# similarity_new("Samsung Galaxy S25 Ultra", "
# - **Solutions:**
#   - Update camera software via *Settings > Software Update*[3][9]."): 0.781212
# similarity_trad("Samsung Galaxy S25 Ultra", "
# - **Solutions:**
#   - Update camera software via *Settings > Software Update*[3][9]."): 0.6543273
# similarity_new("Samsung Galaxy S25 Ultra", "
#   - Clear cache for the camera app in *Settings > Apps > Camera > Storage > Clear Cache*[4]."): 0.7633517
# similarity_trad("Samsung Galaxy S25 Ultra", "
#   - Clear cache for the camera app in *Settings > Apps > Camera > Storage > Clear Cache*[4]."): 0.66376424
# similarity_new("Samsung Galaxy S25 Ultra", "
#   - If problems persist, visit a Samsung service center for hardware inspection[9]."): 0.79388183
# similarity_trad("Samsung Galaxy S25 Ultra", "
#   - If problems persist, visit a Samsung service center for hardware inspection[9]."): 0.70220757
# similarity_new("Samsung Galaxy S25 Ultra", "
#
# #### **4."): 0.76544315
# similarity_trad("Samsung Galaxy S25 Ultra", "
#
# #### **4."): 0.70271677
# similarity_new("Samsung Galaxy S25 Ultra", " Battery Drain**
# - **Problems:** Faster-than-expected battery depletion even under moderate usage."): 0.7365172
# similarity_trad("Samsung Galaxy S25 Ultra", " Battery Drain**
# - **Problems:** Faster-than-expected battery depletion even under moderate usage."): 0.68534577
# similarity_new("Samsung Galaxy S25 Ultra", "
# - **Causes:** High refresh rates, background apps, or Always-On Display."): 0.7674061
# similarity_trad("Samsung Galaxy S25 Ultra", "
# - **Causes:** High refresh rates, background apps, or Always-On Display."): 0.68761903
# similarity_new("Samsung Galaxy S25 Ultra", "
# - **Solutions:**
#   - Check battery usage in *Settings > Battery and Device Care* and restrict power-hungry apps[9]."): 0.77842003
# similarity_trad("Samsung Galaxy S25 Ultra", "
# - **Solutions:**
#   - Check battery usage in *Settings > Battery and Device Care* and restrict power-hungry apps[9]."): 0.6912954
# similarity_new("Samsung Galaxy S25 Ultra", "
#   - Reduce refresh rate to Adaptive or Standard mode via *Settings > Display*[9]."): 0.7808152
# similarity_trad("Samsung Galaxy S25 Ultra", "
#   - Reduce refresh rate to Adaptive or Standard mode via *Settings > Display*[9]."): 0.68532884
# similarity_new("Samsung Galaxy S25 Ultra", "
#   - Disable features like Always-On Display and Location Services when not needed[9]."): 0.7760925
# similarity_trad("Samsung Galaxy S25 Ultra", "
#   - Disable features like Always-On Display and Location Services when not needed[9]."): 0.6792384
# similarity_new("Samsung Galaxy S25 Ultra", "
#
# #### **5."): 0.74184287
# similarity_trad("Samsung Galaxy S25 Ultra", "
#
# #### **5."): 0.70555204
# similarity_new("Samsung Galaxy S25 Ultra", " App Notification Delays**
# - **Problems:** Notifications from apps like WhatsApp and Facebook are delayed."): 0.67742294
# similarity_trad("Samsung Galaxy S25 Ultra", " App Notification Delays**
# - **Problems:** Notifications from apps like WhatsApp and Facebook are delayed."): 0.63281256
# similarity_new("Samsung Galaxy S25 Ultra", "
# - **Causes:** Battery optimization settings or app-specific bugs."): 0.69979656
# similarity_trad("Samsung Galaxy S25 Ultra", "
# - **Causes:** Battery optimization settings or app-specific bugs."): 0.6825584
# similarity_new("Samsung Galaxy S25 Ultra", "
# - **Solutions:**
#   - Disable battery optimization for affected apps in *Settings > Battery > Background Usage Limits*[5]."): 0.7210969
# similarity_trad("Samsung Galaxy S25 Ultra", "
# - **Solutions:**
#   - Disable battery optimization for affected apps in *Settings > Battery > Background Usage Limits*[5]."): 0.68005186
# similarity_new("Samsung Galaxy S25 Ultra", "
#   - Ensure Do Not Disturb mode is turned off[9]."): 0.72010285
# similarity_trad("Samsung Galaxy S25 Ultra", "
#   - Ensure Do Not Disturb mode is turned off[9]."): 0.67629844
# similarity_new("Samsung Galaxy S25 Ultra", "
#   - Update apps to their latest versions via Google Play Store[3]."): 0.7298794
# similarity_trad("Samsung Galaxy S25 Ultra", "
#   - Update apps to their latest versions via Google Play Store[3]."): 0.6406022
# similarity_new("Samsung Galaxy S25 Ultra", "
#
# #### **6."): 0.71536523
# similarity_trad("Samsung Galaxy S25 Ultra", "
#
# #### **6."): 0.6789206
# similarity_new("Samsung Galaxy S25 Ultra", " Android Auto Connectivity Issues**
# - **Problems:** Some users report that Android Auto fails to recognize the device."): 0.6604096
# similarity_trad("Samsung Galaxy S25 Ultra", " Android Auto Connectivity Issues**
# - **Problems:** Some users report that Android Auto fails to recognize the device."): 0.6854416
# similarity_new("Samsung Galaxy S25 Ultra", "
# - **Causes:** Compatibility issues with car head units or software bugs."): 0.6760954
# similarity_trad("Samsung Galaxy S25 Ultra", "
# - **Causes:** Compatibility issues with car head units or software bugs."): 0.6324517
# similarity_new("Samsung Galaxy S25 Ultra", "
# - **Solutions:**
#   - Try a different USB cable or port."): 0.6989263
# similarity_trad("Samsung Galaxy S25 Ultra", "
# - **Solutions:**
#   - Try a different USB cable or port."): 0.66859347
# similarity_new("Samsung Galaxy S25 Ultra", "
#   - Clear cache for Android Auto via *Settings > Apps > Android Auto > Storage > Clear Cache*[4]."): 0.72017354
# similarity_trad("Samsung Galaxy S25 Ultra", "
#   - Clear cache for Android Auto via *Settings > Apps > Android Auto > Storage > Clear Cache*[4]."): 0.67960346
# similarity_new("Samsung Galaxy S25 Ultra", "
#   - Wait for updates from Google to address compatibility issues[3]."): 0.74229723
# similarity_trad("Samsung Galaxy S25 Ultra", "
#   - Wait for updates from Google to address compatibility issues[3]."): 0.64931744
# similarity_new("Samsung Galaxy S25 Ultra", "
#
# ---
#
# ### **Troubleshooting Steps**
#
# #### **Soft Reset (Force Restart)**
# If your device becomes unresponsive:
# 1."): 0.7493377
# similarity_trad("Samsung Galaxy S25 Ultra", "
#
# ---
#
# ### **Troubleshooting Steps**
#
# #### **Soft Reset (Force Restart)**
# If your device becomes unresponsive:
# 1."): 0.70490575
# similarity_new("Samsung Galaxy S25 Ultra", " Press and hold the Volume Down key + Side key simultaneously for at least 7 seconds until the phone restarts[4]."): 0.7641128
# similarity_trad("Samsung Galaxy S25 Ultra", " Press and hold the Volume Down key + Side key simultaneously for at least 7 seconds until the phone restarts[4]."): 0.709344
# similarity_new("Samsung Galaxy S25 Ultra", "
#
# #### **Clear App Cache**
# To resolve app-related issues:
# 1."): 0.79718786
# similarity_trad("Samsung Galaxy S25 Ultra", "
#
# #### **Clear App Cache**
# To resolve app-related issues:
# 1."): 0.6719667
# similarity_new("Samsung Galaxy S25 Ultra", " Navigate to *Settings > Battery and Device Care*."): 0.8249466
# similarity_trad("Samsung Galaxy S25 Ultra", " Navigate to *Settings > Battery and Device Care*."): 0.70950687
# similarity_new("Samsung Galaxy S25 Ultra", "
# 2."): 0.74880534
# similarity_trad("Samsung Galaxy S25 Ultra", "
# 2."): 0.69591045
# similarity_new("Samsung Galaxy S25 Ultra", " Tap "Optimize Now" to clear cache data[4]."): 0.8037271
# similarity_trad("Samsung Galaxy S25 Ultra", " Tap "Optimize Now" to clear cache data[4]."): 0.68984646
# similarity_new("Samsung Galaxy S25 Ultra", "
#
# #### **Factory Reset**
# To resolve persistent problems:
# 1."): 0.8153437
# similarity_trad("Samsung Galaxy S25 Ultra", "
#
# #### **Factory Reset**
# To resolve persistent problems:
# 1."): 0.69631726
# similarity_new("Samsung Galaxy S25 Ultra", " Go to *Settings > General Management > Reset > Factory Data Reset*."): 0.83521765
# similarity_trad("Samsung Galaxy S25 Ultra", " Go to *Settings > General Management > Reset > Factory Data Reset*."): 0.7194175
# similarity_new("Samsung Galaxy S25 Ultra", "
# 2."): 0.7520167
# similarity_trad("Samsung Galaxy S25 Ultra", "
# 2."): 0.69591045
# similarity_new("Samsung Galaxy S25 Ultra", " Confirm reset after backing up important data, as this erases all personal information[5][6]."): 0.84280086
# similarity_trad("Samsung Galaxy S25 Ultra", " Confirm reset after backing up important data, as this erases all personal information[5][6]."): 0.6717035
# similarity_new("Samsung Galaxy S25 Ultra", "
#
# #### **Safe Mode Troubleshooting**
# For issues caused by third-party apps:
# 1."): 0.84026873
# similarity_trad("Samsung Galaxy S25 Ultra", "
#
# #### **Safe Mode Troubleshooting**
# For issues caused by third-party apps:
# 1."): 0.7030379
# similarity_new("Samsung Galaxy S25 Ultra", " Restart into Safe Mode by holding Volume Down + Side key until the Samsung logo appears."): 0.84487635
# similarity_trad("Samsung Galaxy S25 Ultra", " Restart into Safe Mode by holding Volume Down + Side key until the Samsung logo appears."): 0.7170476
# similarity_new("Samsung Galaxy S25 Ultra", "
# 2."): 0.75363237
# similarity_trad("Samsung Galaxy S25 Ultra", "
# 2."): 0.69591045
# similarity_new("Samsung Galaxy S25 Ultra", " Uninstall problematic apps via *Settings > Apps*[4][5]."): 0.8514983
# similarity_trad("Samsung Galaxy S25 Ultra", " Uninstall problematic apps via *Settings > Apps*[4][5]."): 0.6723684
# similarity_new("Samsung Galaxy S25 Ultra", "
#
# ---
#
# ### **Hardware-Specific Features**
#
# #### Galaxy S25 Ultra
# The Ultra model includes unique features such as:
# - S Pen functionality for advanced productivity tasks[2]."): 0.88440967
# similarity_trad("Samsung Galaxy S25 Ultra", "
#
# ---
#
# ### **Hardware-Specific Features**
#
# #### Galaxy S25 Ultra
# The Ultra model includes unique features such as:
# - S Pen functionality for advanced productivity tasks[2]."): 0.8749245
# similarity_new("Samsung Galaxy S25 Ultra", "
# - Enhanced camera capabilities like macro photography and 8K video recording[7]."): 0.8540832
# similarity_trad("Samsung Galaxy S25 Ultra", "
# - Enhanced camera capabilities like macro photography and 8K video recording[7]."): 0.6658476
# similarity_new("Samsung Galaxy S25 Ultra", "
#
# #### Wireless Charging
# All models support wireless charging but may require removing accessories or cases for stable charging performance[2]."): 0.8222624
# similarity_trad("Samsung Galaxy S25 Ultra", "
#
# #### Wireless Charging
# All models support wireless charging but may require removing accessories or cases for stable charging performance[2]."): 0.7052156
# similarity_new("Samsung Galaxy S25 Ultra", "
#
# ---
#
# ### **Service Center Support**
# If troubleshooting fails:
# 1."): 0.8465244
# similarity_trad("Samsung Galaxy S25 Ultra", "
#
# ---
#
# ### **Service Center Support**
# If troubleshooting fails:
# 1."): 0.6560968
# similarity_new("Samsung Galaxy S25 Ultra", " Visit a Samsung service center for hardware repairs or replacements."): 0.8013624
# similarity_trad("Samsung Galaxy S25 Ultra", " Visit a Samsung service center for hardware repairs or replacements."): 0.7137578
# similarity_new("Samsung Galaxy S25 Ultra", "
# 2."): 0.74103826
# similarity_trad("Samsung Galaxy S25 Ultra", "
# 2."): 0.69591045
# similarity_new("Samsung Galaxy S25 Ultra", " Check service center wait times online to minimize delays[4]."): 0.82579905
# similarity_trad("Samsung Galaxy S25 Ultra", " Check service center wait times online to minimize delays[4]."): 0.6228474
# similarity_new("Samsung Galaxy S25 Ultra", "
#
# ---
#
# ### Conclusion
# The Samsung Galaxy S25 series offers cutting-edge technology but may encounter occasional issues typical of new devices."): 0.86664206
# similarity_trad("Samsung Galaxy S25 Ultra", "
#
# ---
#
# ### Conclusion
# The Samsung Galaxy S25 series offers cutting-edge technology but may encounter occasional issues typical of new devices."): 0.8652956
# similarity_new("Samsung Galaxy S25 Ultra", " By following these troubleshooting steps and solutions, users can resolve most problems efficiently while maximizing their smartphone experience."): 0.8265215
# similarity_trad("Samsung Galaxy S25 Ultra", " By following these troubleshooting steps and solutions, users can resolve most problems efficiently while maximizing their smartphone experience."): 0.7171544
# similarity_new("Samsung Galaxy S25 Ultra", " For unresolved issues, professional assistance is available through Samsung service centers."): 0.8121589
# similarity_trad("Samsung Galaxy S25 Ultra", " For unresolved issues, professional assistance is available through Samsung service centers."): 0.69267625

# %%
import numpy as np
import pandas as pd

# Define cosine similarity function
cos_sim = lambda x, y: np.dot(x, y) / (np.linalg.norm(x) * np.linalg.norm(y))

# Example embeddings and chunks (replace with actual data)

embeddings = [np.random.rand(768) for _ in chunks]
embeddings_traditional_chunking = [np.random.rand(768) for _ in chunks]
s25_ultra_embedding = np.random.rand(768)

# Collect results
results = []
for chunk, new_embedding, trad_embeddings in zip(chunks, embeddings, embeddings_traditional_chunking):
    old_score = cos_sim(s25_ultra_embedding, trad_embeddings)
    new_score = cos_sim(s25_ultra_embedding, new_embedding)
    results.append({"query text": "Samsung Galaxy S25 Ultra", "text chunk": chunk, "old score": old_score, "new score": new_score})

# Convert results to DataFrame
df = pd.DataFrame(results)

# Save the DataFrame to a CSV file
df.to_csv('results.csv', index=False)
